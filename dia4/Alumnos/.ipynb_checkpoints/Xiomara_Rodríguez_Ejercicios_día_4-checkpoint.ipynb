# %% [markdown]
# # Ejercicios teóricos

# %% [markdown]
# Xiomara Rodríguez Cáceres
# Ejercicios propuestos tema 4

# %% [markdown]
# ### Ejercicio 1
# ¿Qué consigues con groupby?
# Te permite agrupar, dividir y combinar datos

# %% [markdown]
# ### Ejercicio 2
# ¿Por qué es importante una buena visualizción? La visualización de datos es importate para comunicar información o ideas complejas de forma clara, precisa y eficiente.

# %% [markdown]
# ### Ejercicio 3
# ¿Con qué línea de código muestro una gráfica de barras? ¿Y una de queso?

# %%
import matplotlib.pyplot as plt

cc = ['Andalucía', 'Cataluña', 'Comunitat Valenciana', 'Illes Balears', 'Comunidad de Madrid', 'Canarias','otras CC.AA.']
viajeros = [143378, 230580, 176971, 84139, 39575, 136896, 207869]

plt.bar(range(7), viajeros, color= 'green', )

plt.xticks(range(7), cc, rotation=60)
plt.title("número de turistas según CC.AA. de destino principal 2020") #datos INE, Estadística de Movimientos Turísticos en Fronteras. Dato base.
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 30.0

viajeros = [14.07, 22.62, 17.36, 8.25, 3.88, 13.43, 20.39]
colors= ['red', 'green', 'black', 'magenta', 'cian', 'yellow', 'blue']
cc = ['Andalucía', 'Cataluña', 'Comunitat Valenciana', 'Illes Balears', 'Comunidad de Madrid', 'Canarias','otras CC.AA.']



plt.pie(viajeros, labels= cc)
fig = plt.gcf()
fig.set_size_inches(15,15)
plt.title("% de turistas según CC.AA. de destino principal 2020") #datos INE
plt.show()
fig.savefig("reparto_queso.png")

# %% [markdown]
# ### Ejercicio 4
# ¿Cómo hacer un bot de Telegram? Haz una lista de pasos generales, no quiero que me hables de código.

# %% [markdown]
# 1. Instalar la librería de telegram en Google Colab !pip install telepot
# 2. Abrir telegram
# 3. Buscar en telegram BotFather
# 4. Escribir /star; /newbot; /nombreBot; copiar el token en Google Colab

# %% [markdown]
# # Ejercicios prácticos

# %% [markdown]
# ### Ejercicio 8 del día 3
#
# Agrupa por media por year, month y esta vez también day. Una vez hecho eso muestra la media de generación eólica para el día 3 de junio de 2015

# %%
import pandas as pd
datos = pd.read_csv('https://raw.githubusercontent.com/SerDiaz/Introduccion_programacion_en_python/main/dia3/REE_hist_Tenerife.csv', sep=',', index_col=0) 
print(datos)
# Out:
#         cc  day    dem   die  ele  ...    pre    pro    vap  week  year
# 0    260.2   31  546.4  38.0  0.0  ...  551.0  539.6  196.2     1  2012
# 1    259.2   31  544.8  38.0  0.0  ...  545.1  539.6  195.5     1  2012
# 2    256.2   31  540.3  38.0  0.0  ...  540.7  539.6  195.1     1  2012
# 3    253.4   31  535.1  38.0  0.0  ...  537.8  539.6  194.7     1  2012
# 4    248.6   31  531.2  38.0  0.0  ...  536.2  539.6  194.0     1  2012
# ..     ...  ...    ...   ...  ...  ...    ...    ...    ...   ...   ...
# 343  154.0   18  338.9  37.8  0.0  ...  343.4  330.3  119.5    42  2020
# 344  160.9   18  329.2  37.9  0.0  ...  335.3  330.3  108.6    42  2020
# 345  156.8   18  325.5  38.2  0.0  ...  328.1  330.3  111.3    42  2020
# 346  156.5   18  319.9  37.8  0.0  ...  321.7  330.3  111.5    42  2020
# 347    0.0   18  313.0   0.0  0.0  ...  316.2  330.3    0.0    42  2020
#
# [409994 rows x 23 columns]

# %%
media = datos.groupby(['year', 'month', 'day']).mean()
media.loc[:,['eol']]
# Out:
#                       eol
# year month day
# 2012 12    31    6.433333
# 2013 1     1    13.587500
#            2    10.361806
#            3     6.344444
#            4     0.647222
# ...                   ...
# 2020 10    14   70.983333
#            15   64.843056
#            16   36.760714
#            17   13.287456
#            18   17.184615
#
# [2849 rows x 1 columns]

# %%
media_eol[(media_eol['month'] == 6) & (media_eol['year'] == 2015) & (media_eol['day'] == 3)]
print(media_eol)

# %% [markdown]
# ### Ejercicio 1
# Visualizar la evolución no de los casos totales sino de los casos nuevos de España mediante un gráfico de líneas.

# %%
import pandas as pd
datos = pd.read_csv('https://raw.githubusercontent.com/SerDiaz/Introduccion_programacion_en_python/main/dia4/owid-covid-data.csv') 
datos_españa = datos[datos['location'] == 'Spain']
datos_españa
# Out:
#       iso_code continent  ... life_expectancy human_development_index
# 16906      ESP    Europe  ...           83.56                   0.891
# 16907      ESP    Europe  ...           83.56                   0.891
# 16908      ESP    Europe  ...           83.56                   0.891
# 16909      ESP    Europe  ...           83.56                   0.891
# 16910      ESP    Europe  ...           83.56                   0.891
# ...        ...       ...  ...             ...                     ...
# 17214      ESP    Europe  ...           83.56                   0.891
# 17215      ESP    Europe  ...           83.56                   0.891
# 17216      ESP    Europe  ...           83.56                   0.891
# 17217      ESP    Europe  ...           83.56                   0.891
# 17218      ESP    Europe  ...           83.56                   0.891
#
# [313 rows x 50 columns]

# %%
plt.figure(figsize=(10,10))
x = datos_españa['date']
y = datos_españa['new_cases']
plt.plot(x, y)
plt.show()
condicion = datos_españa.new_cases < 0
columna = "new_cases"
valor_nuevo = 0
datos_españa.loc[condicion, columna] = valor_nuevo

# %% [markdown]
# ### Ejercicio 2
# Ahora hacer lo mismo pero para los casos nuevos y no los totales, con todos los países

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rcParams['font.size'] = 30.0

x_es = datos_españa['date']
x_it = datos_italia['date']
x_ger = datos_alemania['date']
x_fr = datos_francia['date']
x_uk = datos_reinoUnido['date']

y_es = datos_españa['new_cases']
y_it = datos_italia['new_cases']
y_ger = datos_alemania['new_cases']
y_fr = datos_francia['new_cases']
y_uk = datos_reinoUnido['new_cases']

fig = plt.figure(figsize=(14,16))
ax = fig.add_axes([.1, .1, 0.8, 0.8]) # main axes

ax.set_xlabel('Fechas') 
ax.set_ylabel('Nuevos casos') 
ax.set_title('Nuevos casos') 

ax.set_xticklabels(['feb','mar','abr','may','jun',
                    'jul','go','ep','oct','nov', 'dic'])

ax.set_yticks([0,500000,1000000,1500000, 2000000])
ax.set_yticklabels(['0','500 mil','1 mill', '1.5 mill', '2 mill'])

plt.plot(x_es, y_es, lw=3,label = "España")
plt.plot(x_ger, y_ger, lw=3,label = "Alemania")
plt.plot(x_it, y_it, lw=3,label = "Italia")
plt.plot(x_fr, y_fr, lw=3,label = "Francia")
plt.plot(x_uk, y_uk, lw=3,label = "Reino Unido")
plt.legend()

plt.show()
fig.savefig("total_paises.png") # Calidad resolucion

# %% [markdown]
# ### Ejercicio 3
# Ahora hacer lo mismo pero para los casos nuevos con una gráfica de barras pero con Estados Unidos en vez de España

# %%
datos_eeuu = datos[datos['location'] == 'United States']
datos_eeuu
plt.figure(figsize=(10,10))
x = datos_eeuu['date']
y = datos_eeuu['new_cases']
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### Ejercicio 4
#
# Ahora hacer una gráfica de queso para los casos totales sólo de America del Sur.

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['font.size'] = 30.0


datos_sur = datos[datos['continent']=='South America']

values = datos_sur.total_cases
print(len(datos_sur.total_cases))
colors = ['r', 'g', 'b', 'm', 'c','#B3AA19','r', 'g', 'b', 'm', 'c','#B3AA19']
print(len(colors))
labels = datos_sur['location']

plt.pie(datos_sur.total_cases, labels=labels)
fig = plt.gcf()
fig.set_size_inches(15,15) # Para cambiar el tamaño

plt.title('Reparto de casos totales en sudámerica')
plt.show()
fig.savefig("reparto_queso.png") # Calidad resolucion

# %% [markdown]
# ### Ejercicio 5
# Queremos lo mismo de la gráfica de puntos que vimos pero queremos ver la evolución de casos totales con puntos de junio, julio y agosto

# %%
datos.columns.values
# Out:
# array(['cc', 'day', 'dem', 'die', 'ele', 'em_cc', 'em_die', 'em_ele',
#        'em_gas', 'em_vap', 'eol', 'fecha', 'fot', 'gas', 'hid', 'hour',
#        'minute', 'month', 'pre', 'pro', 'vap', 'week', 'year'],
#       dtype=object)

# %%
cond_mes1 = datos['date'].dt.month == 6
cond_mes2 = datos['date'].dt.month == 7
cond_mes3 = datos['date'].dt.month == 8
datos_intervalo = datos[(cond_mes1) & (cond_mes2) & (cond_mes3)]

# %% [markdown]
# ### Ejercicio 6
# Añadir a la esta gráfica que acabamos de ver de Plotly: Reino Unido, Francia, Alemnania, Dinamarca y Bélgica

# %%
## Resolver
